# %% [markdown]
# #CISC 121 - Assignment 1

# %% [markdown]
# 1. Name: Xuanning Wan
# 2. Section: 001
# 3. ID: 20526613
# 4. Github Link of this notebook:
# 5. Chat: https://chatgpt.com/share/68d0bad5-f484-8010-9049-221603672711

# %% [markdown]
# #Problem 1 - FizzBuzz

# %% [markdown]
# 1. Understanding & Breakdown
#
# The question is how to find the special dividend of an integer and assign the specific dividend to a string. I made a simple flowchart below.
#
# ![屏幕截图 2025-09-21 163611.png](data:image/png;base64,...)

# %% [markdown]
# 2. Peer Review & Draft Code
#
# I reviewed a solution under the LeetCode and I find a code example by using Python:
#
# https://leetcode.com/problems/fizz-buzz/solutions/6053128/0-ms-runtime-beats-100-user-confirm-step-by-steps-solution-biginner-friendly/
#
# I understand that he uses the .append() method to store all the output results in a list in sequence. Finally, print this list, which is concise and convenient. I tried to write a draft code myself and referred to his logic:

# %%
n = int(input("Please enter an integer: "))
list = []
for i in range(1,n+1):
  if i % 3 == 0 and i % 5 == 0:
    list.append("FizzBuzz")
  elif i % 3 == 0:
    list.append("Fizz")
  elif i % 5 == 0:
    list.append("Buzz")
  else:
    list.append(str(i))
print(list)
# Out:
# Please enter an integer: 15
# ['1', '2', 'Fizz', '4', 'Buzz', 'Fizz', '7', '8', 'Fizz', 'Buzz', '11', 'Fizz', '13', '14', 'FizzBuzz']

# %% [markdown]
# 3. Final Correct Code
#
# I have asked ChatGPT and I would like to let it help me check mt draft code but I don't take the improvement suggestions because I think that it reverses my code but the result is the same. In summary, I only use AI to check my correctness.

# %%
# Final working solution:
n = int(input("Please enter an integer: "))
list = []
for i in range(1,n+1):
  if i % 3 == 0 and i % 5 == 0:
    list.append("FizzBuzz")
  elif i % 3 == 0:
    list.append("Fizz")
  elif i % 5 == 0:
    list.append("Buzz")
  else:
    list.append(str(i))
print(list)
# Out:
# Please enter an integer: 15
# ['1', '2', 'Fizz', '4', 'Buzz', 'Fizz', '7', '8', 'Fizz', 'Buzz', '11', 'Fizz', '13', '14', 'FizzBuzz']

# %% [markdown]
# [AI Disclaimer : Used ChatGPT with prompt “Please help me check this code
# ."]
# ![屏幕截图 2025-09-21 174321.png](data:image/png;base64,...)

# %% [markdown]
# 4. Review & Fixes

# %%
# Fix 1: Change the method of Output
# Draft version
n = int(input("Please enter an integer: "))
list = []
for i in range(1,n+1):
  if i % 3 == 0 and i % 5 == 0:
    list.append("FizzBuzz")
  elif i % 3 == 0:
    list.append("Fizz")
  elif i % 5 == 0:
    list.append("Buzz")
  else:
    list.append(str(i))
print(list)

# Fixed version
def fizzbuzz(n: int):
  list = []
  for i in range(1,n+1):
    if i % 3 == 0 and i % 5 == 0:
      list.append("FizzBuzz")
    elif i % 3 == 0:
      list.append("Fizz")
    elif i % 5 == 0:
      list.append("Buzz")
    else:
      list.append(str(i))
  return list
fizzbuzz(15)

# %%
# Fix 2: Add some clear comments for explanation
# Draft version
for i in range(1,n+1):
  if i % 3 == 0 and i % 5 == 0:
    list.append("FizzBuzz")
  elif i % 3 == 0:
    list.append("Fizz")
  elif i % 5 == 0:
    list.append("Buzz")
  else:
    list.append(str(i))
# Fixed version
for i in range(1,n+1):
  if i % 3 == 0 and i % 5 == 0: #At first, find the "FizzBuzz". Otherwise it will print "Fizz".
    list.append("FizzBuzz")
  elif i % 3 == 0:
    list.append("Fizz")
  elif i % 5 == 0:
    list.append("Buzz")
  else:
    list.append(str(i)) #Need output the integer in String

# %% [markdown]
# 5. Reflection on Your Contribution
#
# I reviewed some list methods in the comments section of the LeetCode solution. This also made me deepen the logic of using lists instead of storing their values ​​in a variable and then printing them out, because such variables are constantly replaced and may cause bugs.

# %% [markdown]
# #Problem 2 - Palindrome Number

# %% [markdown]
# 1. Understanding & Breakdown
#
# This question requires you to determine whether a string of numbers is a palindrome. It refers to whether it is the same when read forward and backward, such as 121, 1221, 12321.
#
# Flowchart:
#
# ![屏幕截图 2025-09-21 185653.png](data:image/png;base64,...)

# %% [markdown]
# 2. Peer Review & Draft Code
#
# I reviewed a solution under the LeetCode and I find a code example by using Python:
#
# https://leetcode.com/problems/palindrome-number/solutions/5980505/step-by-steps-solution-best-method-beats-100-user-beginner-friendly/
#
# In other people's code, I learned how to reverse the number, and I can loop through each digit of the number. I tried to write a draft code myself but in my own method:

# %%
x = int(input("Please enter an integer: "))
if x < 0 or x > 2**31-1:
  print(False)
else:
  s = str(x)
  if s == s[::-1]:
    print(True)
  else:
    print(False)
# Out:
# Please enter an integer: 123454321
# True

# %% [markdown]
# 3. Final Correct Code
#
# I asked AI to check my code for errors. It can meet the most basic functions, but I used the string method because it is very simple. If I need to use the int method, I need to judge according to each digit, use a loop and it is not efficient. I don't take AI method at the end.

# %%
# Final working solution:

x = int(input("Please enter an integer: "))
if x < 0 or x > 2**31-1:
  print(False)
else:
  s = str(x)
  if s == s[::-1]:
    print(True)
  else:
    print(False)

# %% [markdown]
# [AI Disclaimer : Used ChatGPT with prompt “Please help me check this code ."]![屏幕截图 2025-09-21 194331.png](data:image/png;base64,...)

# %% [markdown]
# 4. Review & Fixes

# %%
# Fix 1: Simplify the main program and use the defined function datatype
# Draft version
x = int(input("Please enter an integer: "))
...
s = str(x)
  if s == s[::-1]:
    print(True)
  else:
    print(False)

# Fixed version
def isPalindrome_str(x: int) -> bool:
  s = str(x)
  return s == s[::-1]
isPalindrome_str()#Test Value

# %%
# Fix 2: Use int method and put test values in a list
# Draft version
x = int(input("Please enter an integer: "))
...
s = str(x)

# Fixed version
def isPalindrome_int(x: int) -> bool:
...
test_value = [121, -121, 10, 0, 12321, 1221, 1001]
[(t, isPalindrome_int(t)) for t in test_value]

# %% [markdown]
# 5. Reflection on Your Contribution
#
# I was able to clearly understand the difference between int and string methods. When using string methods, we can directly use the index to search whether the reversed string is the same as the forward string. At the same time, I also learned how to use mathematical methods to determine whether a number is a palindrome by each digit.

# %% [markdown]
# #Problem 3 - Reverse Integer

# %% [markdown]
# 1. Understanding & Breakdown
#
#
# This problem requires inputting a 32-bit integer and outputting the reverse of each digit. Such as 123 is 321.
#
# Flowchart:
#
# ![屏幕截图 2025-09-21 203945.png](data:image/png;base64,...)

# %% [markdown]
# 2. Peer Review & Draft Code
#
# I reviewed a solution under the LeetCode and I find a code example by using Python:
#
# https://leetcode.com/problems/reverse-integer/solutions/7098763/python-solution-using-remainder/
#
# The solution to this problem is very similar to the previous one. Most people use mathematical methods to solve it, but I still try to solve it with my own string method because it is easy to understand.

# %%
x = int(input("Please enter an integer: "))
if x < -2**31 or x > 2**31-1:
  result = 0
elif x < 0:
  s = str(-x)
  rev = int(s[::-1])
  result = -rev
else:
  s = str(x)
  rev = int(s[::-1])
  result = rev

print(result)
# Out:
# Please enter an integer: -123
# -321

# %% [markdown]
# 3. Final Correct Code
#
# I asked if there was anything wrong with the specific functions of my AI, but in fact everything was normal. This proved that my conjecture in the first step was correct. However, AI pointed out an error that I had not noticed, which is that the reverse number also needs to be within the value range.

# %%
# Final working solution:

x = int(input("Please enter an integer: "))
if x < -2**31 or x > 2**31-1:
  result = 0
else:
  if x < 0:
    s = str(-x)
    rev = int(s[::-1])
    result = -rev
  else:
    s = str(x)
    rev = int(s[::-1])
    result = rev

  if result < -2**31 or result > 2**31-1:
    result = 0

print(result)
# Out:
# Please enter an integer: 1234567899
# 0

# %% [markdown]
# [AI Disclaimer : Used ChatGPT with prompt “Please help me check this code ."]![屏幕截图 2025-09-21 205752.png](data:image/png;base64,...)
#
# ![屏幕截图 2025-09-21 210313.png](data:image/png;base64,...)

# %% [markdown]
# 4. Review & Fixes

# %%
# Fix 1: Control the reverse x in value range
# Draft version
if x < -2**31 or x > 2**31-1:
  result = 0
...

# Fixed version
if x < -2**31 or x > 2**31-1:
  result = 0
...
if result < -2**31 or result > 2**31-1:
    result = 0

# %%
# Fix 2: Changed implementation from string reversal to mathematical digit reversal
# Draft version
...
 s = str(x)
  rev = int(s[::-1])
  result = rev
# Fixed version
...
while x:
  a = x % 10
  x //= 10

# %% [markdown]
# 5. Reflection on Your Contribution
#
# This time, AI pointed out a big mistake for me because I didn't read the question carefully. I just thought the input value should be within the range, but the output result was also the same. And referring to other people's code, I think it gave me a lot of inspiration, because the mathematical method is more logical, which gave me a deeper understanding of the code framework.

# %% [markdown]
# #Problem 4 - Two Sum

# %% [markdown]
# 1. Understanding & Breakdown
#
# For this problem, we need to find the target number when the sum of two numbers in the array is equal to the target number, and output the index of these two numbers.
#
# Flowchart:
#
# ![屏幕截图 2025-09-21 214011.png](data:image/png;base64,...)

# %% [markdown]
# 2. Peer Review & Draft Code
#
# I reviewed a solution under the LeetCode and I find a code example by using Python:
#
# https://leetcode.com/problems/two-sum/solutions/3619262/3-method-s-c-java-python-beginner-friendly/
#
# In his code, I think his thinking logic and ideas are similar to mine. Both use a double loop pattern to find each index in the array and check whether it is equal to the target number.

# %%
nums = [2,7,11,15]
target = 9
result = None
for i in range(len(nums)):
  for j in range(i+1, len(nums)):
    if nums[i] + nums[j] == target:
      result = [i, j]
      break

print(result)
# Out:
# [0, 1]

# %% [markdown]
# 3. Final Correct Code
#
# I asked the AI ​​what was wrong with my code, and it told me that I hadn't ended the double loop, which might have caused unnecessary execution, even if it didn't affect the correctness. Furthermore, I hadn't given it a return value for the case where there was no result. So I improved my original code based on the code it gave me.

# %%
nums = [2,7,11,15]
target = 9
result = None

found = False
for i in range(len(nums)):
  for j in range(i+1, len(nums)):
    if nums[i] + nums[j] == target:
      result = [i, j]
      found = True
      break
  if found:
    break

print(result)
# Out:
# [0, 1]

# %% [markdown]
# [AI Disclaimer : Used ChatGPT with prompt “Please help me check this code ."]
#
# ![屏幕截图 2025-09-21 220206.png](data:image/png;base64,...)
#
# ![屏幕截图 2025-09-21 220230.png](data:image/png;base64,...)

# %% [markdown]
# 4. Review & Fixes

# %%
# Fix 1: Added double loops break
# Draft version
...
  if nums[i] + nums[j] == target:
    result = [i, j]
    break

# Fixed version
...
  if nums[i] + nums[j] == target:
    result = [i, j]
    found = True
    break
if found:
  break

# %%
# Fix 2: Added input fuction
# Draft version
nums = [2,7,11,15]
target = 9

# Fixed version
nums = [2,7,11,15]
target = int(input("Enter the target: "))

# %% [markdown]
# 5. Reflection on Your Contribution
#
# I used AI Level 4 and updated my final code based on the code provided by the AI. I felt that while my code was accurate, it wasn't complete. If the problem had other requirements, my code might become incorrect and break, requiring bug fixes. I needed to continue refining my code.

# %% [markdown]
# #Problem 5 - Valid Palindrome

# %% [markdown]
# 1. Understanding & Breakdown
#
# This problem is very similar to the palindrome problem, except that the numbers are converted into characters, and it reminds me of a palindrome pyramid. But the overall logic is the same, the order of reading from front to back and from back to front should be the same, and the correct or incorrect output should be given.
#
# Flowchart:
#
# ![屏幕截图 2025-09-21 222843.png](data:image/png;base64,...)

# %% [markdown]
# 2. Peer Review & Draft Code
#
# I reviewed a solution under the LeetCode and I find a code example by using Python:
#
# https://leetcode.com/problems/valid-palindrome/solutions/7197820/clean-simple-efficient-beginner-friendly-easy-explanation/
#
# Because of the previous palindrome problem, this problem becomes much simpler. From his code, I can learn a more efficient way to use it in the string method, which can flip the string over with only one loop.

# %%
s = input("Please enter a sentence： ")
l = ""
for x in s:
  if x.isalnum():
    l += x.lower()
if l == l[::-1]:
  print("True")
else:
  print("False")
# Out:
# Please enter a sentence： race a car
# False

# %% [markdown]
# 3. Final Correct Code
#
# I asked the AI ​​if the functionality in my code was complete, and got a positive answer, but the AI ​​also gave me some areas that could be improved in terms of efficiency, but I already felt that it was good enough, so I didn't think I could continue to take its improvements.

# %%
s = input("Please enter a sentence： ")
l = ""
for x in s:
  if x.isalnum():
    l += x.lower()
if l == l[::-1]:
  print("True")
else:
  print("False")
# Out:
# Please enter a sentence： A man, a plan, a canal: Panama
# True

# %% [markdown]
# [AI Disclaimer : Used ChatGPT with prompt “Please help me check this code ."]
#
# ![屏幕截图 2025-09-21 223822.png](data:image/png;base64,...)

# %% [markdown]
# 4. Review & Fixes

# %%
# Fix 1: Clarify variable names
# Draft version
s = input("Please enter a sentence： ")
l = ""
for x in s:

# Fixed version
sentence = input("Please enter a sentence： ")
letter = ""
for index in sentence:

# %%
# Fix 2:Improve the efficiency
# Draft version
if x.isalnum():
  l += x.lower()

# Fixed version
list = []
...
if x.isalnum():
  list.append(x.lower())

# %% [markdown]
# 5. Reflection on Your Contribution
#
#  In this problem, I learned a new method called .isalnum(). It can filter out letters and use the same logic as the previous counting method, using shorter and more efficient code to complete more efficient work.
